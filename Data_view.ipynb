# %%
import torch.nn as nn
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2

from CONSTS import IMAGEPATH

# %%
for img_name in os.listdir(IMAGEPATH):
    img_arr = np.array(Image.open(f'{IMAGEPATH}/{img_name}'))
    print(img_arr.shape)
# Out:
# (825, 550, 3)
# (839, 550, 3)
# (837, 550, 3)
# (825, 550, 3)
# (810, 550, 3)
# (842, 550, 3)
# (834, 550, 3)
# (832, 550, 3)
# (825, 550, 3)
# (825, 550, 3)
# (825, 550, 3)
# (830, 550, 3)
# (810, 550, 3)
# (834, 550, 3)
# (818, 550, 3)
# (828, 550, 3)
# (825, 550, 3)
# (823, 550, 3)
# (817, 550, 3)
# (820, 550, 3)
# (834, 550, 3)
# (841, 550, 3)
# (838, 550, 3)
# (842, 550, 3)
# (836, 550, 3)
# (816, 550, 3)
# (836, 550, 3)
# (835, 550, 3)
# (824, 550, 3)
# (829, 550, 3)
# (830, 550, 3)
# (823, 550, 3)
# (825, 550, 3)
# (830, 550, 3)
# (827, 550, 3)
# (813, 550, 3)
# (825, 550, 3)
# (831, 550, 3)
# (813, 550, 3)
# (806, 550, 3)
# (825, 550, 3)
# (833, 550, 3)
# (820, 550, 3)
# (837, 550, 3)
# (825, 550, 3)
# (838, 550, 3)
# (827, 550, 3)
# (834, 550, 3)
# (825, 550, 3)
# (822, 550, 3)
# (820, 550, 3)
# (825, 550, 3)
# (806, 550, 3)
# (834, 550, 3)
# (812, 550, 3)
# (825, 550, 3)
# (842, 550, 3)
# (825, 550, 3)
# (814, 550, 3)
# (830, 550, 3)
# (825, 550, 3)
# (828, 550, 3)
# ...

# %%
plt.imshow(cv2.resize(img_arr, 
                      (img_arr.shape[1] // 3, img_arr.shape[0] // 3), 
                      interpolation = cv2.INTER_NEAREST))
plt.show()
plt.imshow(cv2.resize(img_arr, (128, 128), interpolation = cv2.INTER_AREA))

# %%
cv2.resize(img_arr, (img_arr.shape[1] // 3, img_arr.shape[0] // 3), interpolation = cv2.INTER_NEAREST).shape
# Out:
# (279, 183, 3)

# %%
img_arr.shape[0]
# Out:
# 838
